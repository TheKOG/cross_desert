# %%
T1={}
T1["node"]=[
    {"type":"start","id":1},
    {"type":"end","id":27},
    {"type":"village","id":15},
    {"type":"mine","id":12}
]
T1["path"]=[
    [1,25,26,27],
    [1,25,24,23,22,9,15],
    [1,25,24,23,22,9,15,14,12],
    [15,14,12],
    [15,9,21,27],
    [12,14,15],
    [12,14,15,9,21,27],
]
T1["weather"]=[None,1,1,0,2,0,1,2,0,1,1
                   ,2,1,0,1,1,1,2,2,1,1
                   ,0,0,1,0,2,1,0,0,1,1]
T1["weight"]=1200
T1["budget"]=10000
T1["income"]=1000

T1["water_price"]=5
T1["water_per_weight"]=3
T1["water_comsumption"]=[5,8,10]

T1["food_price"]=10
T1["food_per_weight"]=2
T1["food_comsumption"]=[7,6,10]

T1["ddl"]=30

import json
with open("T1.json","w") as f:
    json.dump(T1,f)

# %%
T2={}
    
T2["node"]=[
    {"type":"start","id":1},
    {"type":"end","id":64},
    {"type":"village","id":39},
    {"type":"mine","id":30},
    {"type":"village","id":62},
    {"type":"mine","id":55},
]
T2["path"]=[
    [1,9,18,26,27,28,29,30],
    [1,9,18,26,27,28,29,30,39],
    [1,9,18,26,27,28,29,38,46,55],
    [1,9,18,26,27,28,37,45,54,62],
    [1,9,18,26,27,28,37,45,54,62,63,64],
    
    [30,39],
    [30,38,46,54,62],
    [30,39,47,56,64],
    
    [39,30],
    [39,46,55],
    [39,47,56,64],
    
    [55,62],
    [55,47,39],
    [55,63,64],
    
    [62,55],
    [62,55,46,38,30],
    [62,63,64],
]
T2["weather"]=[None,1,1,0,2,0,1,2,0,1,1
                   ,2,1,0,1,1,1,2,2,1,1
                   ,0,0,1,0,2,1,0,0,1,1]
T2["weight"]=1200
T2["budget"]=10000
T2["income"]=1000

T2["water_price"]=5
T2["water_per_weight"]=3
T2["water_comsumption"]=[5,8,10]

T2["food_price"]=10
T2["food_per_weight"]=2
T2["food_comsumption"]=[7,6,10]

T2["ddl"]=30

import json
    
with open("T2.json","w") as f:
    json.dump(T2,f)
